# %%
import robin_stocks as r

# %%
print(r.get_crypto_currency_pairs())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0817412e135c> in <module>()
# ----> 1 print(r.get_latest_price())
#
# TypeError: get_latest_price() missing 1 required positional argument: 'inputSymbols'
